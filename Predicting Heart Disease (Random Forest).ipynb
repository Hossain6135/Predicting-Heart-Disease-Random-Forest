# %% [markdown]
# # Predicting Heart Disease using Random Forest
#
# ## Objective
# To predict the presence of cardiovascular disease using patient medical data.
#
# ## Dataset
# Cardiovascular Disease Dataset from Kaggle.
#
# ## Steps
# 1. Data loading
# 2. Data preprocessing
# 3. Exploratory Data Analysis
# 4. Model training
# 5. Evaluation

# %%
# Libraries for data manipulation, visualization, and numerical operations
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.8.0

# %%
df = pd.read_csv('cardio_train.csv',sep=';')
# Dataset source: https://www.kaggle.com/sulianova/cardiovascular-disease-dataset

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df.shape
# Out:
# (70000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
# Dropping ID
df = df.drop('id',axis = 1)

# %%
# Converting age from days to years
df['age'] = (df['age']/365.25).round(0)

# Medical interpretation is clearer in years than days.

# %%
df
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      50.0       2     168    62.0    110     80            1     1      0
# 1      55.0       1     156    85.0    140     90            3     1      0
# 2      52.0       1     165    64.0    130     70            3     1      0
# 3      48.0       2     169    82.0    150    100            1     1      0
# 4      48.0       1     156    56.0    100     60            1     1      0
# ...     ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  53.0       2     168    76.0    120     80            1     1      1
# 69996  62.0       1     158   126.0    140     90            2     2      0
# 69997  52.0       2     183   105.0    180     90            3     1      0
# 69998  61.0       1     163    72.0    135     80            1     2      0
# 69999  56.0       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
# Visualization: Overall distribution of heart disease cases
# Encoding → 1 = Presence of heart disease, 0 = No heart disease

plt.figure(figsize=(6, 4))
sns.countplot(x='cardio', data=df, palette='colorblind')

plt.title('Heart Disease Distribution', fontsize=13, fontweight='bold')
plt.xlabel('Heart Disease (1 = Yes, 0 = No)')
plt.ylabel('Number of Patients')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13984\963877010.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='cardio', data=df, palette='colorblind')

# %% [markdown]
# The dataset is relatively balanced, so accuracy is a reliable metric.

# %%
# Checking Missing Values
df.isna().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# 1    45530
# 2    24470
# Name: count, dtype: int64

# %%
# Visualization: Heart Disease Distribution by Gender
plt.figure(figsize=(8, 5))

sns.countplot(
    x='gender',
    hue='cardio',
    data=df,
    palette='colorblind',
    edgecolor='black'
)

plt.title('Heart Disease Distribution by Gender', fontsize=14, fontweight='bold')

plt.xlabel('Gender (1 = Female, 2 = Male)', fontsize=11)

plt.ylabel('Number of Patients', fontsize=11)

plt.legend(title='Heart Disease', labels=['No', 'Yes'])

plt.tight_layout()

plt.show()

# %%
# Creating a count plot to show age distribution by heart disease status 
plt.figure(figsize=(14, 6))  

sns.countplot(
    x='age',
    hue='cardio',
    data=df,
    palette='colorblind',
    edgecolor='black'
)

plt.title('Age-wise Distribution of Heart Disease', fontsize=16, fontweight='bold')
plt.xlabel('Age (Years)', fontsize=12)
plt.ylabel('Number of Patients', fontsize=12)

plt.legend(title='Heart Disease', labels=['No', 'Yes'])

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.303157      1.349571    164.359229     74.205690    128.817286
# std        6.760171      0.476838      8.210126     14.395757    154.011419
# min       30.000000      1.000000     55.000000     10.000000   -150.000000
# 25%       48.000000      1.000000    159.000000     65.000000    120.000000
# 50%       54.000000      1.000000    165.000000     72.000000    120.000000
# 75%       58.000000      2.000000    170.000000     82.000000    140.000000
# max       65.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# ...

# %% [markdown]
# Age ranges from 30 to 65, which is medically reasonable.

# %%
df.corr()
# Out:
#                   age    gender    height    weight     ap_hi     ap_lo  \
# age          1.000000 -0.022905 -0.081349  0.053574  0.020458  0.017603
# gender      -0.022905  1.000000  0.499033  0.155406  0.006005  0.015254
# height      -0.081349  0.499033  1.000000  0.290968  0.005488  0.006150
# weight       0.053574  0.155406  0.290968  1.000000  0.030702  0.043710
# ap_hi        0.020458  0.006005  0.005488  0.030702  1.000000  0.016086
# ap_lo        0.017603  0.015254  0.006150  0.043710  0.016086  1.000000
# cholesterol  0.154383 -0.035821 -0.050226  0.141768  0.023778  0.024019
# gluc         0.098443 -0.020491 -0.018595  0.106857  0.011841  0.010806
# smoke       -0.047867  0.338135  0.187989  0.067780 -0.000922  0.005186
# alco        -0.029887  0.170966  0.094419  0.067113  0.001408  0.010601
# active      -0.009848  0.005866 -0.006570 -0.016867 -0.000033  0.004780
# cardio       0.237802  0.008109 -0.010821  0.181660  0.054475  0.065719
#
# ...

# %% [markdown]
# Separating inputs (features) and output (label)

# %%
x = df.drop('cardio',axis = 1)

# %%
x
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      50.0       2     168    62.0    110     80            1     1      0
# 1      55.0       1     156    85.0    140     90            3     1      0
# 2      52.0       1     165    64.0    130     70            3     1      0
# 3      48.0       2     169    82.0    150    100            1     1      0
# 4      48.0       1     156    56.0    100     60            1     1      0
# ...     ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  53.0       2     168    76.0    120     80            1     1      1
# 69996  62.0       1     158   126.0    140     90            2     2      0
# 69997  52.0       2     183   105.0    180     90            3     1      0
# 69998  61.0       1     163    72.0    135     80            1     2      0
# 69999  56.0       1     170    72.0    120     80            2     1      0
#
#        alco  active
# 0         0       1
# ...

# %%
y = df[['cardio']]

# %%
y
# Out:
#        cardio
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ...       ...
# 69995       0
# 69996       1
# 69997       1
# 69998       1
# 69999       0
#
# [70000 rows x 1 columns]

# %% [markdown]
# Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
xtest
# Out:
#         age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 6670   44.0       1     153    93.0    140     90            1     1      0
# 49567  40.0       1     157    89.0    120     80            1     1      0
# 50796  54.0       1     165    66.0    150     90            1     1      0
# 22310  49.0       2     176    88.0    160    100            2     2      1
# 54037  46.0       2     165    78.0    140     90            1     1      0
# ...     ...     ...     ...     ...    ...    ...          ...   ...    ...
# 15691  50.0       1     170    70.0    120     80            1     1      0
# 25200  58.0       1     165    60.0    120     70            3     1      0
# 7366   40.0       1     170    68.0    100     60            1     1      0
# 56399  60.0       1     165    66.0    110     80            1     1      0
# 31206  58.0       1     163    64.0    120     80            1     1      0
#
#        alco  active
# 6670      0       1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
# Random Forest reduces overfitting by averaging multiple trees.

# %%
rf = RandomForestClassifier()

# %%
rf.fit(xtrain,ytrain)
# Out:
# C:\Users\User\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
rf.score(xtest,ytest)
# Out:
# 0.7082857142857143

# %%
from sklearn.tree import DecisionTreeClassifier
# Unrestricted trees tend to overfit.

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(xtest,ytest)
# Out:
# 0.6291428571428571

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = rf.predict(xtest)

print(confusion_matrix(ytest, y_pred))
print(classification_report(ytest, y_pred))
# Out:
# [[7476 2876]
#  [3250 7398]]
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71     10352
#            1       0.72      0.69      0.71     10648
#
#     accuracy                           0.71     21000
#    macro avg       0.71      0.71      0.71     21000
# weighted avg       0.71      0.71      0.71     21000

# %%
# Visualization: Feature importance from Random Forest model
# Showing which features contribute most to heart disease prediction

feature_importance_df = pd.DataFrame({
    'Feature': x.columns,
    'Importance': rf.feature_importances_
}).sort_values(by='Importance', ascending=False)

plt.figure(figsize=(10, 6))

sns.barplot(
    x='Importance',
    y='Feature',
    data=feature_importance_df,
    palette='colorblind',
    edgecolor='black'
)

plt.title('Feature Importance from Random Forest Model', fontsize=14, fontweight='bold')
plt.xlabel('Importance Score')
plt.ylabel('Feature')

plt.tight_layout()

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13984\3938962151.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
